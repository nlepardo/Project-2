# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %% [markdown]
# # Dataset 1
# ## Source Data: [Datasource](https://www.kaggle.com/datasets/miznaaroob/fraudulent-transactions-data)
# ## Brief Description of Data: Use Dataset to predict fraudulent transactions for financial companies
# ## Target: 'isFraud' column
# ## Classification or Regression Problem: Classification
# ## No. of Features: 8
# ## No. of rows: 6,362,620 rows
# ## Challenges foresee in cleaning, exploring, or modelling with this dataset: Missing values

# %%
df1 = pd.read_csv('/content/drive/MyDrive/Machine Learning - Notebooks/Project 2/Fraud.csv')
df1.head()
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0

# %% [markdown]
# # Dataset 2
# ## Source Data: [Datasource](https://www.kaggle.com/datasets/vikasukani/loan-eligible-dataset)
# ## Brief Description of Data: Use Dataset to predict if applicant is eligible for a loan
# ## Target: 'Loan_Status' column
# ## Classification or Regression Problem: Classification
# ## No. of Features: 11
# ## No. of rows: 614 rows
# ## Challenges foresee in cleaning, exploring, or modelling with this dataset: Missing values

# %%
df2 = pd.read_csv('/content/drive/MyDrive/Machine Learning - Notebooks/Project 2/loan-train.csv')
df2.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df2['Loan_Status'].unique()
# Out:
# array(['Y', 'N'], dtype=object)
